# %% [markdown]
# # GEOS 518 Notebook 1: Reading in Time Series Data
# ## By: Taylor Dudunake
# ## January 24, 2018
#
# In this Jupyter Notebook, I use Pandas to read in a dataset, assign defined labels to the data columns, compute a serial date and plot the historical discharge in the Middle Fork Boise River from WY 2001 to WY 2017.
#
# I then extract a time series that goes from the second day of the record to the end (I call it $Q_t$) and another record that goes from the first day to one day prior to the end of the record (I call it $Q_{t-1}$) and save each into a Numpy array. I then plot these two time series against one another looking for the strength of correlation between the time series at a lag of 1-day (the so-called lag 1 autocorrelation).
#
# ## 1. Load the libraries needed and import the data

# %%
import numpy as np # Computations
import pandas as pd # Data management
import matplotlib.pyplot as plt # Plotting

df = pd.read_csv('MF_Boise.csv', names=['Y', 'M', 'D', 'Q (cms)'], skiprows=1)
qrows = np.concatenate([np.arange(0,10,1),np.arange(-11,-1,1)])
df.iloc[qrows,:]
# Out:
#          Y   M   D  Q (cms)
# 0     2000  10   1    8.694
# 1     2000  10   2    9.062
# 2     2000  10   3    8.807
# 3     2000  10   4    8.779
# 4     2000  10   5    8.750
# 5     2000  10   6    8.779
# 6     2000  10   7    8.779
# 7     2000  10   8    8.722
# 8     2000  10   9    8.665
# 9     2000  10  10    8.835
# 6198  2017   9  20   16.481
# 6199  2017   9  21   17.699
# 6200  2017   9  22   16.651
# 6201  2017   9  23   15.745
# 6202  2017   9  24   14.980
# 6203  2017   9  25   14.499
# 6204  2017   9  26   14.216
# 6205  2017   9  27   14.046
# 6206  2017   9  28   13.847
# 6207  2017   9  29   13.593

# %% [markdown]
# ## 2. Compute serial dates
# Now I'm going to use Pandas 'to_datetime' function to turn my columns of years, months, and days to a serial date. This will be helpful when I plot the data so it will plot unambiguously as a time.

# %%
df['SerDates'] = pd.to_datetime(df.Y*10000+df.M*100+df.D, format='%Y%m%d')
df.iloc[qrows,:]
# Out:
#          Y   M   D  Q (cms)   SerDates
# 0     2000  10   1    8.694 2000-10-01
# 1     2000  10   2    9.062 2000-10-02
# 2     2000  10   3    8.807 2000-10-03
# 3     2000  10   4    8.779 2000-10-04
# 4     2000  10   5    8.750 2000-10-05
# 5     2000  10   6    8.779 2000-10-06
# 6     2000  10   7    8.779 2000-10-07
# 7     2000  10   8    8.722 2000-10-08
# 8     2000  10   9    8.665 2000-10-09
# 9     2000  10  10    8.835 2000-10-10
# 6198  2017   9  20   16.481 2017-09-20
# 6199  2017   9  21   17.699 2017-09-21
# 6200  2017   9  22   16.651 2017-09-22
# 6201  2017   9  23   15.745 2017-09-23
# 6202  2017   9  24   14.980 2017-09-24
# 6203  2017   9  25   14.499 2017-09-25
# 6204  2017   9  26   14.216 2017-09-26
# 6205  2017   9  27   14.046 2017-09-27
# 6206  2017   9  28   13.847 2017-09-28
# 6207  2017   9  29   13.593 2017-09-29

# %% [markdown]
# ## 3. Plot the data
#
# Once I loaded in the data to a Pandas dataframe, I plotted it to ensure that there aren't missing data.

# %%
df.plot(x='SerDates', y='Q (cms)', figsize=(14,10)) #Pandas plotting func
plt.show()

# %% [markdown]
# ## 4. Get two time series that are lagged by one $\Delta t$, and plot them against each other

# %%
Q = df['Q (cms)'].values
Qt = Q[1:-1]
Qtm1 = Q[0:-2]

plt.figure(figsize=(14,10))
plt.plot(Qtm1, Qt, 'o')
plt.title('How correlated is today\'s discharge with yesterday\'s?')
plt.xlabel('$Q_{t-1}$ m$^3$/s')
plt.ylabel('$Q_t$ m$^3$/s')
plt.show()

# %% [markdown]
# # 5. Save the dataframe as a pandas "pickle" file

# %%
df.to_pickle('HenrysForkDischarge_WY2001-2015.pkl')
